# %% [markdown]
# ## Assignment 3
# The relavant code parts for the answers are attached
#
# Please ignore the long sentences if you feel overboard. Adding the understanding and required content for my reference

# %% [markdown]
# ## 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# * Functions reduce the need for duplicate code. This makes programs shorter, easier to read, and easier to update.
# * Use of functions enhances the readability of a program. A big code is always difficult to read. Breaking the code in smaller Functions keeps the program organized, easy to understand and makes it reusable.

# %% [markdown]
# ## 2.	When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# * We can call the function by typing its name and putting a value(arguments) in parentheses(if parameters are passed inside the parentheses in the function definition. It turns out that it's possible to define functions with various types of arguments in python.
# * A Function in Python is a piece of code which runs when it is referenced. It is used to utilize the code in more than one place in a program. It is also called method or procedure.
# * Python provides many inbuilt functions like print(), input(), compile(), exec(), etc. but it also gives freedom to create our own functions.

# %% [markdown]
# ## 3.	What statement creates a function?

# %% [markdown]
# * Function in Python is defined by the “def ” statement followed by the function name and parentheses ( () )

# %%
def letsprint():          #defining a function
  print('This is how functions are initialized')

letsprint()               #calling a function
# Out:
# This is how functions are initialized

# %% [markdown]
# ## 4.	What is the difference between a function and a function call?

# %% [markdown]
# * Defining a function is different from “calling a function.” When you “call” a function, you just write the name of the function followed by (); letsprint() referrred to the above example. This will actually run the code inside that function.
# * whereas defining the function does not run the code. It just defines the name.
#
# def letsprint() referrred to the above example.

# %% [markdown]
# ## 5.	How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# **Global (or module) scope** is the top-most scope in a Python program, script, or module. This Python scope contains all of the names that you define at the top level of a program or a module. Names in this Python scope are visible from everywhere in your code.
#
# There's only **one global Python scope** per program execution. This scope remains in existence until the program terminates and all its names are forgotten
#
# **Local (or function) scope** is the code block or body of any Python function or lambda expression. This Python scope contains the names that you define inside the function. These names will only be visible from the code of the function. It’s created at function call, not at function definition, so you’ll have as many different local scopes as function calls. This is true even if you call the same function multiple times, or recursively. Each call will result in a new local scope being created.

# %% [markdown]
# ## 6.	What happens to variables in a local scope when the function call returns?

# %% [markdown]
# When the execution of the function terminates (returns), the local variables are destroyed.

# %% [markdown]
# ## 7.	What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# * The Python return statement is a special statement that you can use inside a function or method to send the function's result back to the caller.
# * A return statement consists of the return keyword followed by an optional return value. The return value of a Python function can be any Python object.
# * In the Python programming language, a user can return multiple values from a function.
# * A return value can be any one of the four variable types: handle, integer, object, or string. The type of value your function returns depends largely on the task it performs.

# %% [markdown]
# ## 8.	If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# * If there is no return statement for a function, its return value is None.
# * A Python function will always have a return value. There is no notion of procedure or routine in Python. So, if you don't explicitly use a return value in a return statement, or if you totally omit the return statement, then Python will implicitly return a default value for you.

# %% [markdown]
# ## 9.	How do you make a function variable refer to the global variable?

# %% [markdown]
# we can use the global keyword to declare which variables are global if we want to refer to a global variable in a function,

# %% [markdown]
# ## 10.	What is the data type of None?

# %% [markdown]
# The None keyword is used to define a null value, or no value at all. None is not the same as 0, False, or an empty string. None is a data type of its own (NoneType) and only None can be None.

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## 11.	What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# That import statement imports a module named areallyourpetsnamederic. May not be in the available modules

# %%
import areallyourpetsnamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b1ea9cb2228f> in <module>()
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 12.	If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# This function can be called with **spam.bacon()**

# %% [markdown]
# ## 13.	What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# Place the line of code that might cause an error in a try clause

# %%
# working of try()
def divide(x, y):
    try:
        # Floor Division : Gives only Fractional Part as Answer
        result = x // y
        print("Yeah ! Your answer is :", result)
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")
 
# Look at parameters and note the working of Program
divide(3, 2)
# Out:
# Yeah ! Your answer is : 1

# %%
divide(3, 0)
# Out:
# Sorry ! You are dividing by zero

# %% [markdown]
# ## 14.	What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# The code that could potentially cause an error goes in the try clause. The example for the same is stated above

# %% [markdown]
# The code that executes if an error happens goes in the except clause.

# %% [markdown]
# The try block lets you test a block of code for errors. The except block lets you handle the error. The else block lets you execute code when there is no error. The finally block lets you execute code, regardless of the result of the try- and except blocks
