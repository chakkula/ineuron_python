# %% [markdown]
# ## Assignment 4
# The relavant code parts for the answers are attached
#
# Please ignore the long sentences if you feel overboard. Adding the understanding and required content for my reference

# %% [markdown]
# ## 1.	What exactly is []?

# %% [markdown]
# The empty list value, which is a list value that contains no items. This is similar to how '' is the empty string value.

# %%
empty_list = []
type(empty_list)
# Out:
# list

# %% [markdown]
# ## 2.	In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam = [2, 4, 6, 8, 10]

#Notice that the third value in a list is at index 2 because the first index is 0.
spam[2] = 'hello' 

print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ## 3.	What is the value of spam[int(int('3' * 2) / 11)]?

# %% [markdown]
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries

# %%
spam = ['a', 'b', 'c', 'd']

# %%
#Note that '3' * 2 is the string '33', which is passed to int() before being divided by 11. This eventually evaluates to 3. Expressions can be used wherever values are used.
print(spam[int(int('3' * 2) / 11)])
# Out:
# d

# %% [markdown]
# ## 4.	What is the value of spam[-1]?

# %%
#Negative indexes count from the end.
print(spam[-1])
# Out:
# d

# %% [markdown]
# ## 5.	What is the value of spam[:2]?

# %%
# start the index from 0 upto 2 excluding index 2
print(spam[:2])
# Out:
# ['a', 'b']

# %% [markdown]
# ## 6.	What is the value of bacon.index('cat')?

# %% [markdown]
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
bacon =  [3.14, 'cat', 11, 'cat', True]

# %%
print(bacon.index('cat'))
# Out:
# 1

# %% [markdown]
# ## 7.	How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ## 8.	How does bacon.remove('cat') change the look of the list in bacon?

# %%
#It removes the first occurence of 'cat'

bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# ## 9.	What are the list concatenation and list replication operators?

# %% [markdown]
# The operator for list concatenation is +, while the operator for replication is *. (This is the same as for strings.)

# %%
con_list = bacon + spam
con_list
# Out:
# [3.14, 11, 'cat', True, 99, 'a', 'b', 'c', 'd']

# %%
rep_list = bacon * 2
rep_list
# Out:
# [3.14, 11, 'cat', True, 99, 3.14, 11, 'cat', True, 99]

# %% [markdown]
# ## 10.	What is difference between the list methods append() and insert()?

# %%
#append() will add values only to the end of a list
bacon.append('add_append')
bacon
# Out:
# [3.14, 11, 'cat', True, 99, 'add_append']

# %%
#insert() can add them anywhere in the list
bacon.insert(4,'insert_here')
bacon
# Out:
# [3.14, 11, 'cat', True, 'insert_here', 99, 'add_append']

# %% [markdown]
# ## 11.	What are the two methods for removing items from a list?

# %%
#The del statement removes the index 4
del bacon[4]
bacon
# Out:
# [3.14, 11, 'cat', True, 99, 'add_append']

# %%
#remove command removes the item in the list
bacon.remove('add_append')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# ## 12.	Describe how list values and string values are identical.

# %% [markdown]
# Both lists and strings can be passed to len(), have indexes and slices, be used in for loops, be concatenated or replicated, and be used with the in and not in operators.

# %% [markdown]
# ## 13.	What's the difference between tuples and lists?

# %% [markdown]
# Lists are mutable; they can have values added, removed, or changed. Tuples are immutable; they cannot be changed at all. Also, tuples are written using parentheses, ( and ), while lists use the square brackets, [ and ].

# %%
list_ex = [1,2,3,4]
list_ex
# Out:
# [1, 2, 3, 4]

# %%
my_tuple = (1, "Hello", 3.4)
my_tuple
# Out:
# (1, 'Hello', 3.4)

# %% [markdown]
# ## 14.	How do you type a tuple value that only contains the integer 42?

# %%
#The trailing comma is mandatory
tup_42 = (42,)
tup_42
# Out:
# (42,)

# %% [markdown]
# ## 15.	How do you get a list value's tuple form? How do you get a tuple value's list form?

# %%
#convert list to tuple
value = ['list', 'to', 'tuple']
my_tuple = tuple(value)
print(my_tuple)
# Out:
# ('list', 'to', 'tuple')

# %%
del list

# %%
# convert tuple to list
value = ('tuple','to','list')
my_list = list(value)
my_list
# Out:
# ['tuple', 'to', 'list']

# %% [markdown]
# ## 16.	Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# They contain references to list values.

# %% [markdown]
# ## 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %%
#The copy.copy() function will do a shallow copy of a list
import copy
check_copy_list = ['Check','copy','copy']
new_list = copy.copy(check_copy_list)

# %%
check_copy_list
# Out:
# ['Check', 'copy', 'copy']

# %%
new_list
# Out:
# ['Check', 'copy', 'copy']

# %%
#the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
new_deepcopy_list = copy.deepcopy(check_copy_list)
new_deepcopy_list
# Out:
# ['Check', 'copy', 'copy']

# %%
check_copy_list[0] = 'add_copy'

# %%
check_copy_list
# Out:
# ['add_copy', 'copy', 'copy']

# %%
new_list
# Out:
# ['Check', 'copy', 'copy']

# %%
new_deepcopy_list
# Out:
# ['Check', 'copy', 'copy']

# %%
#same object for deepcopy
print(id(check_copy_list[0]), id(new_list[0]), id(new_deepcopy_list[0]))
# Out:
# 140019876177584 140019876028720 140019876028720

# %%
new_deepcopy_list2 = copy.deepcopy(check_copy_list)
new_deepcopy_list2
# Out:
# ['add_copy', 'copy', 'copy']

# %%
print(id(check_copy_list[0]), id(new_list[0]), id(new_deepcopy_list2[0]))
# Out:
# 140019876177584 140019876028720 140019876177584

# %%
new_list_copy = copy.copy(check_copy_list)
new_list_copy
# Out:
# ['add_copy', 'copy', 'copy']

# %%
#different object for copy.copy()
print(id(check_copy_list[0]), id(new_list[0]), id(new_deepcopy_list2[0]))
# Out:
# 140019876177584 140019876028720 140019876177584
