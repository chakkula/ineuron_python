# %% [markdown]
# ## 1. Create an assert statement that throws an AssertionError if the variable spam is a negative integer.

# %%
def get_assertion(spam):
  assert spam >= 0, 'The spam variable is negative.'

# %%
get_assertion(10)

# %%
get_assertion(-5)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-31c521e4bb28> in <module>()
# ----> 1 get_assertion(-5)
#
# <ipython-input-1-8e1104c36efc> in get_assertion(spam)
#       1 def get_assertion(spam):
# ----> 2   assert spam >= 0, 'The spam variable is negative.'
#
# AssertionError: The spam variable is negative.

# %% [markdown]
# ## 2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different (that is, 'hello' and 'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).

# %%
def get_assertion(eggs,bacon):
  assert eggs.lower() == bacon.lower(), "The varibles doesn't match."

# %%
get_assertion('hello','hello')

# %%
get_assertion('goodbye','GOODbye')

# %%
get_assertion('goodbye','GOODby')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-ed43b42193d6> in <module>()
# ----> 1 get_assertion('goodbye','GOODby')
#
# <ipython-input-4-6b38330663dc> in get_assertion(eggs, bacon)
#       1 def get_assertion(eggs,bacon):
# ----> 2   assert eggs.lower() == bacon.lower(), "The varibles doesn't match."
#
# AssertionError: The varibles doesn't match.

# %% [markdown]
# ## 3. Create an assert statement that throws an AssertionError every time.

# %%
assert False, "This will throw Assertion error every time"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-c3f29c6d0cdb> in <module>()
# ----> 1 assert False, "This will throw Assertion error every time"
#
# AssertionError: This will throw Assertion error every time

# %% [markdown]
# ## 4. What are the two lines that must be present in your software in order to call logging.debug()?
#
# import and log level specification

# %%
import logging
logging.basicConfig(level=logging.debug, format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
#  2022-06-16 17:03:58,466 - WARNING - This is a warning message
#  2022-06-16 17:03:58,470 - ERROR - This is an error message
#  2022-06-16 17:03:58,476 - CRITICAL - This is a critical message

# %% [markdown]
# ## 5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?

# %%
import logging 
logging.basicConfig(filename='programLog.txt', level=logging.debug, format=' %(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ## 6. What are the five levels of logging?

# %%
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
#  2022-06-16 17:04:14,011 - WARNING - This is a warning message
#  2022-06-16 17:04:14,013 - ERROR - This is an error message
#  2022-06-16 17:04:14,018 - CRITICAL - This is a critical message

# %% [markdown]
# ## 7. What line of code would you add to your software to disable all logging messages?

# %%
logging.disable(logging.error)

# %% [markdown]
# ## 8.Why is using logging messages better than using print() to display the same message?
#
# We can disable logging messages without removing the logging function calls.
#
# We can selectively disable lower-level logging messages.
#
# We can create logging messages. Logging messages provides a timestamp.

# %% [markdown]
# ## 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
#
# The Step button will move the debugger into a function call.
#
# The Over button will quickly execute the function call without stepping into it. The Out button will quickly execute the rest of the code until it steps out of the function it currently is in.

# %% [markdown]
# ## 10.After you click Continue, when will the debugger stop ?
#
# The debugger will stop when it reaches the end of the program or a line with a breakpoint.

# %% [markdown]
# ## 11. What is the concept of a breakpoint?

# %% [markdown]
# breakpoint is a setting on a line of code that causes the debugger to pause when the program execution reaches the line
