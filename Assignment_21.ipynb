# %% [markdown]
# ## 1. Add the current date to the text file today.txt as a string.

# %%
from datetime import date, datetime
now = date.today()
now_str = now.isoformat()
with open('today','wt') as output:
  print(now_str, file=output)

# %% [markdown]
# ## 2. Read the text file today.txt into the string today_string

# %%
with open('today','rt') as input:
  today_string = input.read()

# %%
today_string
# Out:
# '2022-06-17\n'

# %% [markdown]
# ## 3. Parse the date from today_string.

# %%
format = '%Y-%m-%d\n'
datetime.strptime(today_string, format)
# Out:
# datetime.datetime(2022, 6, 17, 0, 0)

# %% [markdown]
# ## 4. List the files in your current directory

# %%
import os
os.listdir('.')
# Out:
# ['.config', 'today', 'sample_data']

# %% [markdown]
# ## 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
os.listdir('..')
# Out:
# ['dev',
#  'bin',
#  'tmp',
#  'sys',
#  'home',
#  'lib',
#  'var',
#  'etc',
#  'srv',
#  'boot',
#  'opt',
#  'run',
#  'proc',
#  'root',
#  'media',
#  'sbin',
#  'lib64',
#  'usr',
#  'mnt',
#  'content',
#  '.dockerenv',
#  'tools',
#  'datalab',
#  'tensorflow-1.15.2',
#  'lib32',
#  'python-apt']

# %% [markdown]
# ## 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing

# %%
def now(seconds):
  from datetime import date, datetime
  from time import sleep
  sleep(seconds)
  print('wait',seconds,'seconds, time is', datetime.utcnow())

if __name__=='__main__':
  import random
  for n in range(3):
    seconds = random.random()
    proc = multiprocessing.Process(target=now, args=(seconds,))
    proc.start()
# Out:
# wait 0.11388238287209695 seconds, time is 2022-06-17 23:47:45.999689

# %% [markdown]
# ## 7. Create a date object of your day of birth.

# %%
my_day = date(1994,7,29)
my_day
# Out:
# datetime.date(1994, 7, 29)

# %% [markdown]
# ## 8. What day of the week was your day of birth?

# %%
my_day.weekday()
# Out:
# 4

# %%
my_day.isoweekday()
# Out:
# 5

# %% [markdown]
# ## 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
oldestest = my_day + timedelta(days=10000)

# %%
oldestest
# Out:
# datetime.date(2021, 12, 14)
