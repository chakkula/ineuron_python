# %% [markdown]
# ## 1. What is the result of the code, and why?

# %%
def func(a, b=6, c=8):
  print(a, b, c)

# %%
func(1, 2)
# Out:
# 1 2 8

# %% [markdown]
# The function has three arguments that are declared with default values for 2nd and 3rd arguments to be 6 and 8. This means that the function passed with 1 argument needs a value mandatorily but for 2nd and 3rd it considers the value if passed else consider the default value to be the argument that is declared.
#
# In the above function the 2nd argument passed has the value 2 so the function considered the vaue 2 for the argument replacing the declared value 6. Since no argument is passed for 3rd it has considered the default value 8 and printed the same.

# %% [markdown]
# ## 2. What is the result of this code, and why?

# %%
def func(a, b, c=5):
  print(a, b, c)

# %%
func(1, c=3, b=2)
# Out:
# 1 2 3

# %% [markdown]
# The above explanation stands valid, here the only change to be considered here is that argument passage doesn't require any order unless we don't use the variable assigned to it.

# %% [markdown]
# ## 3. How about this code: what is its result, and why?

# %%
def func(a, *pargs):
  print(a, pargs)

# %%
func(1, 2, 3)
# Out:
# 1 (2, 3)

# %% [markdown]
# The special syntax *args in function definitions in python is used to pass a variable number of arguments to a function. It is used to pass a non-key worded, variable-length argument list.

# %% [markdown]
# ## 4. What does this code print, and why?

# %%
def func(a, **kargs):
  print(a, kargs)

# %% [markdown]
# The special syntax **kwargs in function definitions in python is used to pass a keyworded, variable-length argument list. We use the name kwargs with the double star. The reason is because the double star allows us to pass through keyword arguments

# %%
func(a=1, c=3, b=2)
# Out:
# 1 {'c': 3, 'b': 2}

# %% [markdown]
# One can think of the kwargs as being a dictionary that maps each keyword to the value that we pass alongside it. That is why when we iterate over the kwargs there doesn’t seem to be any order in which they were printed out.

# %% [markdown]
# ## 5. What gets printed by this, and explain?

# %%
def func(a, b, c=8, d=5): 
  print(a, b, c, d)

# %%
func(1, *(5, 6))
# Out:
# 1 5 6 5

# %% [markdown]
# the func() contains 2 non keyworded arguments passed o it resulted with 5, 6 replacing the values for b, and c=8. The default value for d got printed as nothing is passed for it.

# %% [markdown]
# ## 6. what is the result of this, and explain?

# %%
def func(a, b, c): 
  a = 2
  b[0] = 'x'
  c['a'] = 'y'

# %%
l=1; m=[1]; n={'a':0}

# %%
#printing the values assigned to it
print(l)
print(m)
print(n)
# Out:
# 1
# [1]
# {'a': 0}

# %%
func(l, m, n)

# %%
l, m, n
# Out:
# (1, ['x'], {'a': 'y'})

# %%
#The value of c passed is changing the value for the key for the dictionary n 
c = {'a':0}
c['a']='y'
c
# Out:
# {'a': 'y'}

# %%
#Similarly it is cahnging the index 0 value of the list m to 'x'
m=[1]
m[0]='x'
m
# Out:
# ['x']
