# %% [markdown]
# ## 1.	Write a Python program to print "Hello Python"?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# ## 2.	Write a Python program to do arithmetical operations addition and division.?

# %%
# Addition
print('Add 2 and 5:', 5+2)

#subtraction
print('Subtract 2 from 5:', 5-2)

#multiplication
print('Multiply 2 and 3:', 2*3)

#Division
print('what is 5 divided by 2:',5/2)
# Out:
# Add 2 and 5: 7
# Subtract 2 from 5: 3
# Multiply 2 and 3: 6
# what is 5 divided by 2: 2.5

# %% [markdown]
# ## 3.	Write a Python program to find the area of a triangle?

# %%
# Area of traingle formula is 1/2*base*height
base = 10
height = 10
Area = (base * height)/2
print("Area of triangle is: ", Area)
# Out:
# Area of triangle is:  50.0

# %% [markdown]
# ## 4.	Write a Python program to swap two variables?

# %%
#swapping two varibles
a = 10
b = 20
a,b = b, a
print('a is ', a)
print('b is ', b)
# Out:
# a is  20
# b is  10

# %% [markdown]
# ## 5.	Write a Python program to generate a random number?

# %%
import random

#generate a random number in the range of 0 to 50
print(random.randint(25,50))
print(random.randrange(10))
# Out:
# 29
# 8
